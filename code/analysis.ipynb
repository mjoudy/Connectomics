# %%
# for test data and results easily

# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import nest.raster_plot

from iter_loadtxt import iter_loadtxt

# %%
loc = os.getcwd()
#sig_name = 'fluorescence_mocktest.txt'
sig_name = 'calcium-10e5-tau-10.npy'
loc_signal = loc[: -4] + 'data/' + sig_name

# %%
fluorscence_signal = iter_loadtxt(loc_signal)
np.shape(fluorscence_signal)
# Out:
# (48428, 100)

# %%
#just to see how its look like. the signal isn't spike so it doesn't make any sense.
nest.raster_plot.from_data(fluorscence_signal)

# %%
selection_signal = fluorscence_signal[:, 50:53]

# %%
# %matplotlib qt

plt.figure(1)
plt.subplot(3,1,1)
plt.plot(selection_signal[0:10000, 0], )
plt.subplot(3,1,2)
plt.plot(selection_signal[0:10000, 1], )
plt.subplot(3,1,3)
plt.plot(selection_signal[0:10000, 2], )
#plt.show()

# %%
fluorscence_signal = np.load(loc_signal)
np.shape(fluorscence_signal)
# Out:
# (1250, 99000)

# %%
selection_signal_2 = fluorscence_signal[200:203, :]

# %%
# %matplotlib notebook

plt.figure(2)
plt.subplot(3,1,1)
plt.plot(selection_signal_2[0, 0:10000])
plt.subplot(3,1,2)
plt.plot(selection_signal_2[1, 0:10000])
plt.subplot(3,1,3)
plt.plot(selection_signal_2[2, 0:10000])
plt.show()
